# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 2.8 MB 14.7 MB/s
# ...
#      |████████████████████████████████| 636 kB 85.7 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 76.1 MB/s
# ...
#      |████████████████████████████████| 895 kB 87.8 MB/s
# ...
#      |████████████████████████████████| 52 kB 1.3 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
from transformers import GPTNeoForCausalLM, GPT2Tokenizer
model = GPTNeoForCausalLM.from_pretrained("EleutherAI/gpt-neo-1.3B")
tokenizer = GPT2Tokenizer.from_pretrained("EleutherAI/gpt-neo-1.3B")

prompt = "In a shocking finding, scientists discovered a herd of unicorns living in a remote, " \
         "previously unexplored valley, in the Andes Mountains. Even more surprising to the " \
         "researchers was the fact that the unicorns spoke perfect English."

input_ids = tokenizer(prompt, return_tensors="pt").input_ids

gen_tokens = model.generate(input_ids, do_sample=True, temperature=0.9, max_length=100,)
gen_text = tokenizer.batch_decode(gen_tokens)[0]
# Out:
# Downloading:   0%|          | 0.00/1.35k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.31G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/200 [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
gen_text
# Out:
# 'In a shocking finding, scientists discovered a herd of unicorns living in a remote, previously unexplored valley, in the Andes Mountains. Even more surprising to the researchers was the fact that the unicorns spoke perfect English.\n\n"The evidence, that has never been reported before, is that the unicorns speak perfectly and communicate through language, and that they use the same sign language to communicate with each other, which is a sign language that is rare to find anywhere else," said the researchers'

# %%
prompt_patients = "Task is to classify patient health outcomes. symptoms: patient has high blood pressure and mania. outcome: patient is sick. symptoms: patient is doing well with no health concerns. outcome: patient is healthy. symptoms: patient has a broken leg and is in a coma. outcome:"

# %%
input_ids = tokenizer(prompt_patients, return_tensors="pt").input_ids

gen_tokens = model.generate(input_ids, do_sample=True, temperature=0.9, max_length=100,)
gen_text = tokenizer.batch_decode(gen_tokens)[0]
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
gen_text
# Out:
# 'Task is to classify patient health outcomes. symptoms: patient has high blood pressure and mania. outcome: patient is sick. symptoms: patient is doing well with no health concerns. outcome: patient is healthy. symptoms: patient has a broken leg and is in a coma. outcome: patient is healthy.\n\nA binary classification problem is concerned with assigning one value to one class and zero to the other class. We need a machine to classify these. For example, if a program needs to classify'

# %%
startup_prompt = "This is a list of startup ideas: " \
"1. [Tag: Internet] A website that lets you post articles you've written, and other people can help you edit them."\
"2. [Tag: Home] A website that lets you share a photo of something broken in your house, and then local people can offer to fix it for you."\
"3. [Tag: Children] An online service that teaches children how to code."\
"4. [Tag: Financial] An online service that allows people to rent out their unused durable goods to people who need them."\
"5. [Tag: Machine Learning]"

# %%
input_ids = tokenizer(startup_prompt, return_tensors="pt").input_ids

gen_tokens = model.generate(input_ids, do_sample=True, temperature=0.9, max_length=150,)
gen_text = tokenizer.batch_decode(gen_tokens)[0]
gen_text
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# "This is a list of startup ideas: 1. [Tag: Internet] A website that lets you post articles you've written, and other people can help you edit them.2. [Tag: Home] A website that lets you share a photo of something broken in your house, and then local people can offer to fix it for you.3. [Tag: Children] An online service that teaches children how to code.4. [Tag: Financial] An online service that allows people to rent out their unused durable goods to people who need them.5. [Tag: Machine Learning] An online service that can automatically perform various mathematical functions.6. [Tag: Health Care] An online service to help people find doctors who can help"
